# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("/content/obesity.csv")
print(df)
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2111, step=1)

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.size
# Out:
# 35887

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2104 non-null   object
#  5   FAVC                            2099 non-null   object
#  6   FCVC                            2106 non-null   float64
#  7   NCP                             2106 non-null   float64
#  8   CAEC                            2110 non-null   object
#  9   SMOKE                           2108 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2105 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2106.000000  2106.000000
# mean     24.312600     1.701677    86.586058     2.418786     2.687006
# std       6.345968     0.093305    26.191172     0.534083     0.777189
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.665528
# 50%      22.777890     1.700499    83.000000     2.384104     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2110.000000
# mean      2.008011     1.010298     0.657494
# std       0.612953     0.850592     0.608831
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
df.sample() # display randon row
# Out:
#     Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 370   Male  19.0     1.8    60.0                             no  yes   2.0
#
#      NCP       CAEC SMOKE  CH2O SCC  FAF  TUE CALC                 MTRANS  \
# 370  3.0  Sometimes    no   1.0  no  1.0  1.0   no  Public_Transportation
#
#         NObeyesdad
# 370  Normal_Weight

# %%
df.sample(5) # display randon 5 rows
# Out:
#      Gender        Age    Height     Weight family_history_with_overweight  \
# 354  Female  17.000000  1.600000  59.000000                             no
# 514  Female  22.142432  1.596110  42.848033                             no
# 596    Male  17.469417  1.798645  59.612717                            yes
# 700    Male  17.758315  1.854162  59.881316                            yes
# 543  Female  23.000000  1.710182  50.287967                            yes
#
#     FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 354  yes  2.000000  3.000000   Sometimes    no  2.000000  no  1.000000
# 514   no  3.000000  2.581015  Frequently    no  2.654702  no  0.902095
# 596  yes  2.336044  4.000000   Sometimes    no  2.000000  no  2.000000
# 700  yes  2.966126  3.969810   Sometimes    no  2.000000  no  2.000088
# 543  yes  2.000000  3.000000  Frequently    no  2.099863  no  1.635810
#
#           TUE CALC                 MTRANS           NObeyesdad
# ...

# %%
df.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
df['Age']
# Out:
# 0       21.000000
# 1       21.000000
# 2       23.000000
# 3       27.000000
# 4       22.000000
#           ...
# 2106    20.976842
# 2107    21.982942
# 2108    22.524036
# 2109    24.361936
# 2110    23.664709
# Name: Age, Length: 2111, dtype: float64

# %%
df.nunique()
# Out:
# Gender                               2
# Age                               1402
# Height                            1574
# Weight                            1525
# family_history_with_overweight       2
# FAVC                                 2
# FCVC                               809
# NCP                                632
# CAEC                                 4
# SMOKE                                2
# CH2O                              1268
# SCC                                  2
# FAF                               1190
# TUE                               1128
# CALC                                 4
# MTRANS                               5
# NObeyesdad                           7
# dtype: int64

# %%
df.count()
# Out:
# Gender                            2111
# Age                               2111
# Height                            2111
# Weight                            2111
# family_history_with_overweight    2104
# FAVC                              2099
# FCVC                              2106
# NCP                               2106
# CAEC                              2110
# SMOKE                             2108
# CH2O                              2111
# SCC                               2105
# FAF                               2111
# TUE                               2110
# CALC                              2110
# MTRANS                            2111
# NObeyesdad                        2111
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2106    False
# 2107    False
# 2108    False
# 2109    False
# 2110    False
# Length: 2111, dtype: bool

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Age       24.312600
# Height     1.701677
# Weight    86.586058
# FCVC       2.418786
# NCP        2.687006
# CH2O       2.008011
# FAF        1.010298
# TUE        0.657494
# dtype: float64

# %%
df.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Age        6.345968
# Height     0.093305
# Weight    26.191172
# FCVC       0.534083
# NCP        0.777189
# CH2O       0.612953
# FAF        0.850592
# TUE        0.608831
# dtype: float64

# %%
df.min()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Gender                     Female
# Age                          14.0
# Height                       1.45
# Weight                       39.0
# FCVC                          1.0
# NCP                           1.0
# CH2O                          1.0
# FAF                           0.0
# TUE                           0.0
# MTRANS                 Automobile
# NObeyesdad    Insufficient_Weight
# dtype: object

# %%
df.max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Gender                       Male
# Age                          61.0
# Height                       1.98
# Weight                      173.0
# FCVC                          3.0
# NCP                           4.0
# CH2O                          3.0
# FAF                           3.0
# TUE                           2.0
# MTRANS                    Walking
# NObeyesdad    Overweight_Level_II
# dtype: object

# %%
df.nsmallest(2,'Age')
# Out:
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 415    Male  14.0    1.71    72.0                            yes  yes   3.0
# 116  Female  15.0    1.65    86.0                            yes  yes   3.0
#
#      NCP       CAEC SMOKE  CH2O SCC  FAF  TUE CALC   MTRANS      NObeyesdad
# 415  3.0  Sometimes    no   3.0  no  2.0  1.0   no  Walking   Normal_Weight
# 116  3.0  Sometimes    no   1.0  no  3.0  2.0   no  Walking  Obesity_Type_I

# %%
df.nlargest(2,'Age')
# Out:
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 133  Female  61.0    1.65    66.0                             no  yes   3.0
# 252    Male  56.0    1.79    90.0                            yes   no   2.0
#
#      NCP       CAEC SMOKE  CH2O SCC  FAF  TUE        CALC  \
# 133  3.0     Always    no   2.0  no  1.0  1.0  Frequently
# 252  3.0  Sometimes   yes   2.0  no  1.0  0.0  Frequently
#
#                     MTRANS           NObeyesdad
# 133  Public_Transportation        Normal_Weight
# 252             Automobile  Overweight_Level_II

# %%
df.memory_usage(deep=True)
# Out:
# Index                                128
# Gender                            130857
# Age                                16888
# Height                             16888
# Weight                             16888
# family_history_with_overweight    126079
# FAVC                              126082
# FCVC                               16888
# NCP                                16888
# CAEC                              139018
# SMOKE                             124512
# CH2O                               16888
# SCC                               124483
# FAF                                16888
# TUE                                16888
# CALC                              134893
# MTRANS                            158596
# NObeyesdad                        154509
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index                               128
# Gender                            16888
# Age                               16888
# Height                            16888
# Weight                            16888
# family_history_with_overweight    16888
# FAVC                              16888
# FCVC                              16888
# NCP                               16888
# CAEC                              16888
# SMOKE                             16888
# CH2O                              16888
# SCC                               16888
# FAF                               16888
# TUE                               16888
# CALC                              16888
# MTRANS                            16888
# NObeyesdad                        16888
# dtype: int64

# %%
df.corr()
# Out:
#              Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# Age     1.000000 -0.025958  0.202560  0.016168 -0.046027 -0.045304 -0.144938
# Height -0.025958  1.000000  0.463136 -0.038627  0.242884  0.213376  0.294709
# Weight  0.202560  0.463136  1.000000  0.214678  0.106191  0.200575 -0.051436
# FCVC    0.016168 -0.038627  0.214678  1.000000  0.039468  0.068615  0.019774
# NCP    -0.046027  0.242884  0.106191  0.039468  1.000000  0.057597  0.128936
# CH2O   -0.045304  0.213376  0.200575  0.068615  0.057597  1.000000  0.167236
# FAF    -0.144938  0.294709 -0.051436  0.019774  0.128936  0.167236  1.000000
# TUE    -0.296737  0.052113 -0.071437 -0.100405  0.037026  0.011978  0.058121
#
#              TUE
# Age    -0.296737
# Height  0.052113
# Weight -0.071437
# FCVC   -0.100405
# NCP     0.037026
# CH2O    0.011978
# FAF     0.058121
# TUE     1.000000

# %%
df.count()
# Out:
# Gender                            2111
# Age                               2111
# Height                            2111
# Weight                            2111
# family_history_with_overweight    2104
# FAVC                              2099
# FCVC                              2106
# NCP                               2106
# CAEC                              2110
# SMOKE                             2108
# CH2O                              2111
# SCC                               2105
# FAF                               2111
# TUE                               2110
# CALC                              2110
# MTRANS                            2111
# NObeyesdad                        2111
# dtype: int64

# %%
df['NObeyesdad'].value_counts()
# Out:
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: NObeyesdad, dtype: int64

# %%
print(df)
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df.head() # displays top 5 rows
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.head() # displays top 5 rows
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df[3:10] # displays rows from 3 to 9 - 10 excluded
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
# 5    Male  29.0    1.62    53.0                             no  yes   2.0
# 6  Female  23.0    1.50    55.0                            yes  yes   3.0
# 7    Male  22.0    1.64    53.0                             no   no   2.0
# 8    Male  24.0    1.78    64.0                            yes  yes   3.0
# 9    Male  22.0    1.72    68.0                            yes  NaN   2.0
#
#    NCP       CAEC SMOKE  CH2O SCC  FAF  TUE        CALC  \
# 3  3.0  Sometimes    no   2.0  no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0  no  0.0  0.0   Sometimes
# 5  3.0  Sometimes    no   2.0  no  0.0  0.0   Sometimes
# 6  3.0  Sometimes    no   2.0  no  1.0  0.0   Sometimes
# 7  3.0  Sometimes    no   2.0  no  3.0  0.0   Sometimes
# ...

# %%
df[['Gender','Age']]
# Out:
#       Gender        Age
# 0     Female  21.000000
# 1     Female  21.000000
# 2       Male  23.000000
# 3       Male  27.000000
# 4       Male  22.000000
# ...      ...        ...
# 2106  Female  20.976842
# 2107  Female  21.982942
# 2108  Female  22.524036
# 2109  Female  24.361936
# 2110  Female  23.664709
#
# [2111 rows x 2 columns]

# %%
df.NObeyesdad.value_counts()
# Out:
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: NObeyesdad, dtype: int64

# %%
print(df.columns)
dss=df.drop(columns=['FAF'])
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
dss.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'TUE', 'CALC',
#        'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df.isna()
# Out:
#       Gender    Age  Height  Weight  family_history_with_overweight   FAVC  \
# 0      False  False   False   False                           False  False
# 1      False  False   False   False                           False  False
# 2      False  False   False   False                           False  False
# 3      False  False   False   False                           False  False
# 4      False  False   False   False                           False  False
# ...      ...    ...     ...     ...                             ...    ...
# 2106   False  False   False   False                           False  False
# 2107   False  False   False   False                           False  False
# 2108   False  False   False   False                           False  False
# 2109   False  False   False   False                           False  False
# 2110   False  False   False   False                           False  False
#
# ...

# %%
df.isna().sum()
# Out:
# Gender                             0
# Age                                0
# Height                             0
# Weight                             0
# family_history_with_overweight     7
# FAVC                              12
# FCVC                               5
# NCP                                5
# CAEC                               1
# SMOKE                              3
# CH2O                               0
# SCC                                6
# FAF                                0
# TUE                                1
# CALC                               1
# MTRANS                             0
# NObeyesdad                         0
# dtype: int64

# %%
df.isna().all()
# Out:
# Gender                            False
# Age                               False
# Height                            False
# Weight                            False
# family_history_with_overweight    False
# FAVC                              False
# FCVC                              False
# NCP                               False
# CAEC                              False
# SMOKE                             False
# CH2O                              False
# SCC                               False
# FAF                               False
# TUE                               False
# CALC                              False
# MTRANS                            False
# NObeyesdad                        False
# dtype: bool

# %%
df.isna().any()
# Out:
# Gender                            False
# Age                               False
# Height                            False
# Weight                            False
# family_history_with_overweight     True
# FAVC                               True
# FCVC                               True
# NCP                                True
# CAEC                               True
# SMOKE                              True
# CH2O                              False
# SCC                                True
# FAF                               False
# TUE                                True
# CALC                               True
# MTRANS                            False
# NObeyesdad                        False
# dtype: bool

# %%
df.shape
# Out:
# (2111, 17)

# %%
print(df.shape)
ds=df.dropna()
ds.shape
# Out:
# (2111, 17)
# (2072, 17)

# %%
print(df)
dc=df.fillna('notdefined')
dc
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
dn=df.fillna(0)
dn
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
Visualization

# %%
print(df.Gender.value_counts())
# Visualize frequency count of male / female for given obesity  dataset using bar graph
df.Gender.value_counts().plot.bar()
# Out:
# Male      1068
# Female    1043
# Name: Gender, dtype: int64

# %%
print(df.Age.value_counts())
# Visualize frequency count of Age group in given dataset
df.Age.value_counts().plot.bar()
# Out:
# 18.000000    128
# 26.000000    101
# 21.000000     96
# 23.000000     89
# 19.000000     59
#             ...
# 23.320120      1
# 34.243146      1
# 18.549437      1
# 36.310292      1
# 23.664709      1
# Name: Age, Length: 1402, dtype: int64

# %%
print(df.Height.value_counts())
# Visualize frequency count of Age group in given dataset
df.Height.value_counts().plot.bar()
# Out:
# 1.700000    60
# 1.650000    50
# 1.600000    43
# 1.750000    39
# 1.620000    36
#             ..
# 1.842943     1
# 1.706082     1
# 1.704141     1
# 1.705813     1
# 1.738836     1
# Name: Height, Length: 1574, dtype: int64

# %%
print(df.Weight.value_counts())
# Visualize frequency count of Age group in given dataset
df.Weight.value_counts().plot.bar()
# Out:
# 80.000000     59
# 70.000000     43
# 50.000000     42
# 75.000000     40
# 60.000000     37
#               ..
# 65.140408      1
# 87.279890      1
# 67.083121      1
# 90.138680      1
# 133.472641     1
# Name: Weight, Length: 1525, dtype: int64

# %%
print(df.family_history_with_overweight.value_counts())
# Visualize frequency count of Age group in given dataset
df.family_history_with_overweight.value_counts().plot.bar()
# Out:
# yes    1719
# no      385
# Name: family_history_with_overweight, dtype: int64

# %%
print(df.FAVC.value_counts())
# Visualize frequency count of Age group in given dataset
df.FAVC.value_counts().plot.bar()
# Out:
# yes    1857
# no      242
# Name: FAVC, dtype: int64

# %%
print(df.FCVC.value_counts())
# Visualize frequency count of Age group in given dataset
df.FCVC.value_counts().plot.bar()
# Out:
# 3.000000    650
# 2.000000    598
# 1.000000     33
# 2.823179      2
# 2.214980      2
#            ...
# 2.927409      1
# 2.706134      1
# 2.010684      1
# 2.300408      1
# 2.680375      1
# Name: FCVC, Length: 809, dtype: int64

# %%
print(df.NCP.value_counts())
# Visualize frequency count of Age group in given dataset
df.NCP.value_counts().plot.bar()
# Out:
# 3.000000    1202
# 1.000000     198
# 4.000000      69
# 2.776840       2
# 3.985442       2
#             ...
# 2.756405       1
# 3.054899       1
# 3.118013       1
# 3.335876       1
# 1.089048       1
# Name: NCP, Length: 632, dtype: int64

# %%
print(df.CAEC.value_counts())
# Visualize frequency count of Age group in given dataset
df.CAEC.value_counts().plot.bar()
# Out:
# Sometimes     1764
# Frequently     242
# Always          53
# no              51
# Name: CAEC, dtype: int64

# %%
print(df.SMOKE.value_counts())
# Visualize frequency count of Age group in given dataset
df.SMOKE.value_counts().plot.bar()
# Out:
# no     2064
# yes      44
# Name: SMOKE, dtype: int64

# %%
print(df.CH2O.value_counts())
# Visualize frequency count of Age group in given dataset
df.CH2O.value_counts().plot.bar()
# Out:
# 2.000000    448
# 1.000000    211
# 3.000000    162
# 2.825629      3
# 1.636326      3
#            ...
# 1.622638      1
# 2.452986      1
# 2.035954      1
# 1.944095      1
# 2.863513      1
# Name: CH2O, Length: 1268, dtype: int64

# %%
print(df.SCC.value_counts())
# Visualize frequency count of Age group in given dataset
df.SCC.value_counts().plot.bar()
# Out:
# no     2009
# yes      96
# Name: SCC, dtype: int64

# %%
print(df.FAF.value_counts())
# Visualize frequency count of Age group in given dataset
df.FAF.value_counts().plot.bar()
# Out:
# 0.000000    411
# 1.000000    234
# 2.000000    183
# 3.000000     75
# 0.110174      2
#            ...
# 1.916751      1
# 0.954459      1
# 0.340915      1
# 0.986414      1
# 1.026452      1
# Name: FAF, Length: 1190, dtype: int64

# %%
print(df.TUE.value_counts())
# Visualize frequency count of Age group in given dataset
df.TUE.value_counts().plot.bar()
# Out:
# 0.000000    557
# 1.000000    292
# 2.000000    109
# 0.630866      4
# 1.119877      3
#            ...
# 1.019452      1
# 0.673408      1
# 0.997600      1
# 1.313363      1
# 0.714137      1
# Name: TUE, Length: 1128, dtype: int64

# %%
print(df.CALC.value_counts())
# Visualize frequency count of Age group in given dataset
df.CALC.value_counts().plot.bar()
# Out:
# Sometimes     1401
# no             638
# Frequently      70
# Always           1
# Name: CALC, dtype: int64

# %%
print(df.MTRANS.value_counts())
# Visualize frequency count of Age group in given dataset
df.MTRANS.value_counts().plot.bar()
# Out:
# Public_Transportation    1580
# Automobile                457
# Walking                    56
# Motorbike                  11
# Bike                        7
# Name: MTRANS, dtype: int64

# %%
print(df.NObeyesdad.value_counts())
# Visualize frequency count of Age group in given dataset
df.NObeyesdad.value_counts().plot.bar()
# Out:
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: NObeyesdad, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.title('Gender Wise Ananlysis') # add title
plt.xlabel("Gender of Passengers") # adds x -axis label
plt.ylabel("Age of Passengers") # adds y -axis label
plt.bar(df.Gender,df.Age) # generates bar graph
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(8,8))
#Creating bar plot using seaborn
sns.barplot(x = 'Age',y = 'Gender',data = df,palette = "Blues")
#sns.barplot(x = 'Gender',y = 'Age',data = df,palette = "Blues")
#Adding the aesthetics
plt.title('Comparative Wise Ananlysis')
plt.xlabel('Age of Passengers')
plt.ylabel('Gender of Passengers')
# Show the plot
plt.show()

# %%
sns.barplot(x = 'Age',y = 'Gender',hue = 'NObeyesdad',data = df, palette = "Blues")
#Adding the aesthetics
plt.title('Comparative Ananlysis')
plt.xlabel('Age of Passengers')
plt.ylabel('Gender of Passengers')
# Show the plot
plt.show()

# %%
df.Age.hist()

# %%
print(df.Age.min(),df.Age.max())
df.hist(column="Age",by="Gender",bins=10)
# Out:
# 14.0 61.0
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f10740e8d10>,
# ...
#       dtype=object)

# %%
df.hist(column="Age", by="NObeyesdad", bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1073c7ef10>,
# ...
#       dtype=object)

# %%
df.Weight.hist()

# %%
df.FCVC.hist()

# %%
df.NCP.hist()

# %%
df.CAEC.hist()

# %%
df.CH2O.hist()

# %%
df.FAF.hist()

# %%
df.TUE.hist()

# %%
sns.scatterplot(x = df.Gender,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.Age,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.Weight,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.Height,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.family_history_with_overweight,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.FCVC,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.NCP,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.CAEC,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.SMOKE,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.CH2O,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.SCC,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.FAF,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.TUE,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.CALC,y=df.NObeyesdad)

# %%
sns.scatterplot(x = df.MTRANS,y=df.NObeyesdad)

# %%
df.Age.plot.barh()

# %%
df.Age.plot.area()

# %%
df.Age.plot.box()

# %%
df.Weight.plot.box()

# %%
df.Height.plot.box()

# %%
df.Weight.plot.box()

# %%
df.FCVC.plot.box()

# %%
df.NCP.plot.box()

# %%
df.CH2O.plot.box()

# %%
df.FAF.plot.box()

# %%
df.TUE.plot.box()

# %%
sns.pointplot(data=df,x='Age',y='NObeyesdad')

# %%
sns.pointplot(data=df,x='Height',y='NObeyesdad')

# %%
sns.pointplot(data=df,x='Weight',y='NObeyesdad')

# %%
sns.pointplot(data=df,x='FCVC',y='NObeyesdad')

# %%
sns.pointplot(data=df,x='NCP',y='NObeyesdad')

# %%
sns.pointplot(data=df,x='CH2O',y='NObeyesdad')

# %%
sns.pointplot(data=df,x='FAF',y='NObeyesdad')

# %%
sns.pointplot(data=df,x='TUE',y='NObeyesdad')

# %%
sns.pointplot(data=df,x='Age',y='Weight',hue='NObeyesdad')

# %%
df2=df[["Age","Weight","Height","SCC"]]
plt.figure()
sns.pairplot(df2)
plt.show()

# %%
sns.heatmap(df.corr())

# %%
plt.figure()
sns.heatmap(df2.corr(), annot=True)
plt.show()

# %%
sns.lineplot(data=df.SCC)

# %%
sns.lineplot(data=df.FAF)

# %%
sns.lineplot(data=df.Gender)

# %%
sns.lineplot(data=df.Weight)

# %%
sns.lineplot(data=df.Height)

# %%
sns.lineplot(data=df.TUE)

# %%
sns.lineplot(data=df.SMOKE)

# %%
#regional plot
sns.regplot(x='Age',y='TUE', data=df)

# %%
#regional plot
sns.regplot(x='Age',y='NCP', data=df)

# %%
# Draw an enhanced box plot for larger datasets.
sns.boxenplot(data=df.Age)

# %%
sns.catplot(data=df,x="Age",y="NObeyesdad",kind="box")

# %%
sns.catplot(data=df,x="Weight",y="NObeyesdad",kind="box")

# %%
#violin plot(it shows several quantitative data across one or more categorical variables)
sns.violinplot(data=df.Age)

# %%
#relational plot(it provides access to several different axes-level functions that show th
sns.relplot(x=df.Age,y=df.SCC,hue=df.NObeyesdad)

# %%
#relational plot(it provides access to several different axes-level functions that show th
sns.relplot(x=df.FAF,y=df.TUE,hue=df.NObeyesdad)

# %%
#relational plot(it provides access to several different axes-level functions that show th
sns.relplot(x=df.SMOKE,y=df.NCP,hue=df.NObeyesdad)

# %%
sns.lineplot(x=df.Age,y=df.Weight)

# %%
sns.lineplot(x=df.FCVC,y=df.SMOKE)

# %%
# Generates heatmap for data correlation matrix with values
# color map sytles : https://matplotlib.org/stable/tutorials/colors/colormaps.html
sns.heatmap(df.corr(),annot=True,cmap='Reds')

# %%
# pairplot
sns.pairplot(df=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-194-ac36afdac73b> in <module>
#       1 # pairplot
# ----> 2 sns.pairplot(df=df)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: pairplot() got an unexpected keyword argument 'df'

# %%
# generate bar chart in horizontal way for entire dataset
df.count().plot.barh()

# %%
# Area plot
df.plot.area()

# %%
# Area plot
df.plot.area(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f1062aa3710>,
# ...
#       dtype=object)

# %%
sns.displot(x=df.Age,y=df.NCP)

# %%
# Scatterplot - 3 columns
sns.scatterplot(x='SMOKE',y='CALC',hue='NObeyesdad',data=df)

# %%
sns.regplot(x=df.FCVC,y=df.Age)

# %%
sns.regplot(x='NCP',y='Age',color='g',data=df,marker='+')

# %%
sns.relplot(x=df.FAVC,y=df.Age)

# %%
sns.relplot(x=df.SMOKE,y=df.Age,hue=df.NObeyesdad,s=80)

# %%
# 4 variables age, survived , passenger id and Sex and size =80 , style is survived
sns.relplot(x=df.SMOKE,y=df.Age,hue=df.FCVC,style=df.NObeyesdad,s=80)

# %%
df.Age.plot.kde()
